# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.1/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="JLYiB8IEMYjtqmF8jdwF")
project = rf.workspace("skinburn-wdrjx").project("fall-detection-06c4m")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# Train YOLO11n on COCO8 for 3 epochs
# !yolo detect train model=yolo11n.pt data=/content/Fall-Detection-1/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 84.1MB/s]
# Ultralytics 8.3.99 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('/content/runs/detect/train/weights/best.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model('/content/Fall-Detection-1/test/images/Image_11_jpg.rf.ba1cc19bec0b68d3bb8c601169f9ba15.jpg',save=True)  # predict on an image
# Out:
# image 1/1 /content/Fall-Detection-1/test/images/Image_11_jpg.rf.ba1cc19bec0b68d3bb8c601169f9ba15.jpg: 640x640 1 normal, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://ultralytics.com/hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLO11 on [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/) datasets. See [YOLO11 Train Docs](https://docs.ultralytics.com/modes/train/) for more information.
